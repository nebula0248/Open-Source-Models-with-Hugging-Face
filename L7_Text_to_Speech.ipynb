# %% [markdown]
# # Lesson 7: Text to Speech

# %% [markdown]
# - In the classroom, the libraries are already installed for you.
# - If you would like to run this code on your own machine, you can install the following:

# %%
# !pip install transformers
# !pip install gradio
# !pip install timm
# !pip install timm
# !pip install inflect
# !pip install phonemizer
# Out:
# Requirement already satisfied: transformers in /opt/app-root/lib/python3.9/site-packages (4.41.1)
# Requirement already satisfied: packaging>=20.0 in /opt/app-root/lib/python3.9/site-packages (from transformers) (24.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/app-root/lib/python3.9/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from transformers) (2.32.2)
# Requirement already satisfied: numpy>=1.17 in /opt/app-root/lib/python3.9/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: filelock in /opt/app-root/lib/python3.9/site-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /opt/app-root/lib/python3.9/site-packages (from transformers) (0.23.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/app-root/lib/python3.9/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/app-root/lib/python3.9/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/app-root/lib/python3.9/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/app-root/lib/python3.9/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/app-root/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/app-root/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers) (2024.2.2)
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: gradio in /opt/app-root/lib/python3.9/site-packages (4.31.5)
# Requirement already satisfied: ffmpy in /opt/app-root/lib/python3.9/site-packages (from gradio) (0.3.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: numpy~=1.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (1.26.4)
# Requirement already satisfied: urllib3~=2.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (2.2.1)
# Requirement already satisfied: orjson~=3.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (3.10.3)
# Requirement already satisfied: tomlkit==0.12.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: pydub in /opt/app-root/lib/python3.9/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (10.3.0)
# Requirement already satisfied: gradio-client==0.16.4 in /opt/app-root/lib/python3.9/site-packages (from gradio) (0.16.4)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (2.2.2)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.9/site-packages (from gradio) (24.0)
# Requirement already satisfied: jinja2<4.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (3.1.4)
# Requirement already satisfied: pydantic>=2.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (2.7.1)
# Requirement already satisfied: typer<1.0,>=0.12 in /opt/app-root/lib/python3.9/site-packages (from gradio) (0.12.3)
# Requirement already satisfied: ruff>=0.2.2 in /opt/app-root/lib/python3.9/site-packages (from gradio) (0.4.5)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (4.11.0)
# Requirement already satisfied: semantic-version~=2.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: fastapi in /opt/app-root/lib/python3.9/site-packages (from gradio) (0.111.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/app-root/lib/python3.9/site-packages (from gradio) (0.0.9)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (5.3.0)
# Requirement already satisfied: markupsafe~=2.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (2.1.5)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /opt/app-root/lib/python3.9/site-packages (from gradio) (6.4.0)
# Requirement already satisfied: matplotlib~=3.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (3.8.4)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /opt/app-root/lib/python3.9/site-packages (from gradio) (0.23.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (22.1.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /opt/app-root/lib/python3.9/site-packages (from gradio) (0.30.0)
# Requirement already satisfied: httpx>=0.24.1 in /opt/app-root/lib/python3.9/site-packages (from gradio) (0.27.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /opt/app-root/lib/python3.9/site-packages (from gradio-client==0.16.4->gradio) (11.0.3)
# Requirement already satisfied: fsspec in /opt/app-root/lib/python3.9/site-packages (from gradio-client==0.16.4->gradio) (2024.3.1)
# Requirement already satisfied: jsonschema>=3.0 in /opt/app-root/lib/python3.9/site-packages (from altair<6.0,>=4.2.0->gradio) (4.22.0)
# Requirement already satisfied: toolz in /opt/app-root/lib/python3.9/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: certifi in /opt/app-root/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: idna in /opt/app-root/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (3.7)
# Requirement already satisfied: httpcore==1.* in /opt/app-root/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: anyio in /opt/app-root/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (4.3.0)
# Requirement already satisfied: sniffio in /opt/app-root/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/app-root/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (2.32.2)
# Requirement already satisfied: filelock in /opt/app-root/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (3.14.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/app-root/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.4)
# Requirement already satisfied: zipp>=3.1.0 in /opt/app-root/lib/python3.9/site-packages (from importlib-resources<7.0,>=1.3->gradio) (3.18.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/app-root/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/app-root/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (4.51.0)
# Requirement already satisfied: cycler>=0.10 in /opt/app-root/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.9/site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/app-root/lib/python3.9/site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: pydantic-core==2.18.2 in /opt/app-root/lib/python3.9/site-packages (from pydantic>=2.0->gradio) (2.18.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/app-root/lib/python3.9/site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/app-root/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in /opt/app-root/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: rich>=10.11.0 in /opt/app-root/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio) (12.6.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /opt/app-root/lib/python3.9/site-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: email_validator>=2.0.0 in /opt/app-root/lib/python3.9/site-packages (from fastapi->gradio) (2.1.1)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /opt/app-root/lib/python3.9/site-packages (from fastapi->gradio) (0.0.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /opt/app-root/lib/python3.9/site-packages (from fastapi->gradio) (5.10.0)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/app-root/lib/python3.9/site-packages (from email_validator>=2.0.0->fastapi->gradio) (2.6.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/app-root/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/app-root/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/app-root/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/app-root/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.12.1)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/app-root/lib/python3.9/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /opt/app-root/lib/python3.9/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.9.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/app-root/lib/python3.9/site-packages (from anyio->httpx>=0.24.1->gradio) (1.2.1)
# Requirement already satisfied: httptools>=0.5.0 in /opt/app-root/lib/python3.9/site-packages (from uvicorn>=0.14.0->gradio) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in /opt/app-root/lib/python3.9/site-packages (from uvicorn>=0.14.0->gradio) (0.22.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/app-root/lib/python3.9/site-packages (from uvicorn>=0.14.0->gradio) (0.19.0)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/app-root/lib/python3.9/site-packages (from uvicorn>=0.14.0->gradio) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.3.2)
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting timm
#   Downloading timm-1.0.3-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 29.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: torch in /opt/app-root/lib/python3.9/site-packages (from timm) (2.2.2+cu121)
# Requirement already satisfied: huggingface_hub in /opt/app-root/lib/python3.9/site-packages (from timm) (0.23.2)
# Requirement already satisfied: pyyaml in /opt/app-root/lib/python3.9/site-packages (from timm) (6.0.1)
# Requirement already satisfied: torchvision in /opt/app-root/lib/python3.9/site-packages (from timm) (0.17.2+cu121)
# Requirement already satisfied: safetensors in /opt/app-root/lib/python3.9/site-packages (from timm) (0.4.3)
# Requirement already satisfied: packaging>=20.9 in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (24.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (4.66.4)
# Requirement already satisfied: filelock in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (3.14.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (4.11.0)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (2.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: sympy in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (1.12)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (10.3.2.106)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (11.0.2.54)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.0.106)
# Requirement already satisfied: triton==2.2.0 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (2.2.0)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (11.4.5.107)
# Requirement already satisfied: jinja2 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: networkx in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (2.19.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/app-root/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->timm) (12.5.40)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/app-root/lib/python3.9/site-packages (from torchvision->timm) (10.3.0)
# Requirement already satisfied: numpy in /opt/app-root/lib/python3.9/site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.9/site-packages (from jinja2->torch->timm) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: mpmath>=0.19 in /opt/app-root/lib/python3.9/site-packages (from sympy->torch->timm) (1.3.0)
# Installing collected packages: timm
# Successfully installed timm-1.0.3
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: timm in /opt/app-root/lib/python3.9/site-packages (1.0.3)
# Requirement already satisfied: torch in /opt/app-root/lib/python3.9/site-packages (from timm) (2.2.2+cu121)
# Requirement already satisfied: pyyaml in /opt/app-root/lib/python3.9/site-packages (from timm) (6.0.1)
# Requirement already satisfied: torchvision in /opt/app-root/lib/python3.9/site-packages (from timm) (0.17.2+cu121)
# Requirement already satisfied: huggingface_hub in /opt/app-root/lib/python3.9/site-packages (from timm) (0.23.2)
# Requirement already satisfied: safetensors in /opt/app-root/lib/python3.9/site-packages (from timm) (0.4.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (24.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (2024.3.1)
# Requirement already satisfied: filelock in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (3.14.0)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from huggingface_hub->timm) (2.32.2)
# Requirement already satisfied: triton==2.2.0 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (2.2.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (8.9.2.26)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.3.1)
# Requirement already satisfied: jinja2 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: networkx in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (2.19.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (12.1.0.106)
# Requirement already satisfied: sympy in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (1.12)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (11.0.2.54)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (11.4.5.107)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/app-root/lib/python3.9/site-packages (from torch->timm) (10.3.2.106)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/app-root/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->timm) (12.5.40)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/app-root/lib/python3.9/site-packages (from torchvision->timm) (10.3.0)
# Requirement already satisfied: numpy in /opt/app-root/lib/python3.9/site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.9/site-packages (from jinja2->torch->timm) (2.1.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (2.2.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/app-root/lib/python3.9/site-packages (from sympy->torch->timm) (1.3.0)
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting inflect
#   Downloading inflect-7.2.1-py3-none-any.whl (34 kB)
# Collecting typeguard>=4.0.1
#   Downloading typeguard-4.3.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: typing-extensions in /opt/app-root/lib/python3.9/site-packages (from inflect) (4.11.0)
# Collecting more-itertools
#   Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=3.6 in /opt/app-root/lib/python3.9/site-packages (from typeguard>=4.0.1->inflect) (7.1.0)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.9/site-packages (from importlib-metadata>=3.6->typeguard>=4.0.1->inflect) (3.18.2)
# Installing collected packages: more-itertools, typeguard, inflect
# Successfully installed inflect-7.2.1 more-itertools-10.2.0 typeguard-4.3.0
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting phonemizer
#   Downloading phonemizer-3.2.1-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=18.1 in /opt/app-root/lib/python3.9/site-packages (from phonemizer) (23.2.0)
# Collecting dlinfo
#   Downloading dlinfo-1.2.1-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: typing-extensions in /opt/app-root/lib/python3.9/site-packages (from phonemizer) (4.11.0)
# Requirement already satisfied: joblib in /opt/app-root/lib/python3.9/site-packages (from phonemizer) (1.4.2)
# Collecting segments
#   Downloading segments-2.2.1-py2.py3-none-any.whl (15 kB)
# Collecting clldutils>=1.7.3
#   Downloading clldutils-3.22.2-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 24.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: regex in /opt/app-root/lib/python3.9/site-packages (from segments->phonemizer) (2024.5.15)
# Collecting csvw>=1.5.6
#   Downloading csvw-3.3.0-py2.py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 215.9 MB/s eta 0:00:00
# Requirement already satisfied: markdown in /opt/app-root/lib/python3.9/site-packages (from clldutils>=1.7.3->segments->phonemizer) (3.6)
# Collecting lxml
#   Downloading lxml-5.2.2-cp39-cp39-manylinux_2_28_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 59.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tabulate>=0.7.7 in /opt/app-root/lib/python3.9/site-packages (from clldutils>=1.7.3->segments->phonemizer) (0.9.0)
# Collecting colorlog
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 217.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: markupsafe in /opt/app-root/lib/python3.9/site-packages (from clldutils>=1.7.3->segments->phonemizer) (2.1.5)
# Collecting bibtexparser>=2.0.0b4
#   Downloading bibtexparser-2.0.0b7-py3-none-any.whl (38 kB)
# Requirement already satisfied: python-dateutil in /opt/app-root/lib/python3.9/site-packages (from clldutils>=1.7.3->segments->phonemizer) (2.9.0.post0)
# Collecting rdflib
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 118.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from csvw>=1.5.6->segments->phonemizer) (2.32.2)
# Requirement already satisfied: babel in /opt/app-root/lib/python3.9/site-packages (from csvw>=1.5.6->segments->phonemizer) (2.15.0)
# Requirement already satisfied: jsonschema in /opt/app-root/lib/python3.9/site-packages (from csvw>=1.5.6->segments->phonemizer) (4.22.0)
# Collecting language-tags
#   Downloading language_tags-1.2.0-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.4/213.4 kB 257.3 MB/s eta 0:00:00
# Collecting uritemplate>=3.0.0
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 215.4 MB/s eta 0:00:00
# Requirement already satisfied: colorama in /opt/app-root/lib/python3.9/site-packages (from csvw>=1.5.6->segments->phonemizer) (0.4.6)
# Collecting rfc3986<2
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: six in /opt/app-root/lib/python3.9/site-packages (from isodate->csvw>=1.5.6->segments->phonemizer) (1.16.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/app-root/lib/python3.9/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (0.18.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/app-root/lib/python3.9/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/app-root/lib/python3.9/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (0.35.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/app-root/lib/python3.9/site-packages (from markdown->clldutils>=1.7.3->segments->phonemizer) (7.1.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /opt/app-root/lib/python3.9/site-packages (from rdflib->csvw>=1.5.6->segments->phonemizer) (3.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (3.7)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown->clldutils>=1.7.3->segments->phonemizer) (3.18.2)
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136816 sha256=052be80ee1903a7dcc2a38bad3263ad77f58a498efb5240b48ab170ec55f7408
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0fni57k8/wheels/a3/68/66/2f15abd0673d83c02f354115feedeb89c3daed2ac319b11090
# Successfully built pylatexenc
# Installing collected packages: rfc3986, pylatexenc, language-tags, dlinfo, uritemplate, lxml, isodate, colorlog, bibtexparser, rdflib, clldutils, csvw, segments, phonemizer
# Successfully installed bibtexparser-2.0.0b7 clldutils-3.22.2 colorlog-6.8.2 csvw-3.3.0 dlinfo-1.2.1 isodate-0.6.1 language-tags-1.2.0 lxml-5.2.2 phonemizer-3.2.1 pylatexenc-2.10 rdflib-7.0.0 rfc3986-1.5.0 segments-2.2.1 uritemplate-4.1.1
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# **Note:**  `py-espeak-ng` is only available Linux operating systems.
#
# To run locally in a Linux machine, follow these commands:
# ```
#     sudo apt-get update
#     sudo apt-get install espeak-ng
#     pip install py-espeak-ng
# ```

# %%
# !pip install py-espeak-ng
# Out:
# Collecting py-espeak-ng
#   Downloading py_espeak_ng-0.1.8-py2.py3-none-any.whl (6.3 kB)
# Installing collected packages: py-espeak-ng
# Successfully installed py-espeak-ng-0.1.8
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Build the `text-to-speech` pipeline using the 🤗 Transformers Library

# %% [markdown]
# - Here is some code that suppresses warning messages.

# %%
from transformers.utils import logging

logging.set_verbosity_error()

# %%
from transformers import pipeline
import torch

narrator = pipeline("text-to-speech",
                    model="kakao-enterprise/vits-ljs",
                    device=0 if torch.cuda.is_available() else -1) # Use GPU if available, if not, use CPU

# %% [markdown]
# Info about [kakao-enterprise/vits-ljs](https://huggingface.co/kakao-enterprise/vits-ljs)

# %%
text = """
Researchers at the Allen Institute for AI, \
HuggingFace, Microsoft, the University of Washington, \
Carnegie Mellon University, and the Hebrew University of \
Jerusalem developed a tool that measures atmospheric \
carbon emitted by cloud servers while training machine \
learning models. After a model’s size, the biggest variables \
were the server’s location and time of day it was active.
"""

# %%
narrated_text = narrator(text)

# %%
from IPython.display import Audio as IPythonAudio

IPythonAudio(narrated_text["audio"][0],
             rate=narrated_text["sampling_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Try it yourself!
# - Try this model with your own text to speech examples!
